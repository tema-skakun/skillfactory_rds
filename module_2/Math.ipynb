# %% [markdown]
# **Пропуски** — отсутствие значений в данных. Обычно это случается из-за ошибок человека: забыли, какие данные не внесли, не всё перенесли из другого документа, неверно заполнили документ, случайно удалили часть данных. Например, при опросе респонденты отвечали только на часть вопросов, не указывая какие-то данные.
#
# Что делать с пропусками?
#
#    -**Удалить пропуски**: удалить строки с пропусками, если таких строк немного, или столбцы (признаки) в данных, если их много, и это не повлияет на результат в целом.
#
#    -**Заменить пропуски**: заменить на среднее значение (медианой) или на самый часто попадающийся вариант. Например, опрос респондентов проходил в Москве, вероятнее, большинство — жители города, а не туристы. Значит, в графе город можно поставить «Москва». Или же по другим данным в документе можно восстановить пол людей, которые его не указали.
#
#    -**Записать новое значение**: например, вместо пропуска в столбце «Пол» указать «не определён».
#
#    -**Заменить алгоритмами МО**: признак можно считать целевой переменной и обучать модель, чтобы предсказать пропущенные значения.
#
#
#    **Выброс** — результат измерения, который выделяется из общей выборки. Выбросы появляются из-за ошибок в данных и сильно выделяющихся среди остальных значений. Их нужно **искать и удалять**, иначе данные будут подстраиваться под них и давать неверный результат.
#
# Как искать выбросы:
#
#     Поиск и удаление по порогу
#     Способ нахождения выбросов, основанный на здравом смысле и методе пристального взгляда. Посмотреть данные и поискать невозможные и нелогичные значения, например, в столбце «высота здания» стоит 30 км.
#     Поиск с помощью статистики
#     Поиск с помощью здравого смысла трудно автоматизировать, поэтому эффективнее статистические методы. Например, поиск по отклонению или по распределению IQR (interquartile range, межквартильное расстояние).
#     Поиск с помощью DBSCAN
#     Поиск с помощью методов кластеризации, один из таких методов — DBSCAN, который может автоматически находить шум в данных.
#
# Разные способы поиска выбросов могут давать разные результаты. Не всегда выделяющееся значение будет являться выбросом, возможно, у нас пока просто не хватает данных.

# %% [markdown]
# # 2.8. Итоговое задание

# %% [markdown]
# Вас пригласили поучаствовать в одном из проектов UNICEF — международного подразделения ООН, чья миссия состоит в повышении уровня благополучия детей по всему миру.
#
# **Суть проекта — отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.**
#
# И сделать это можно с помощью модели, которая предсказывала бы результаты госэкзамена по математике для каждого ученика школы (вот она, сила ML!). Чтобы определиться с параметрами будущей модели, проведите разведывательный анализ данных и составьте отчёт по его результатам.

# %% [markdown]
# Описание датасета
#
# Посмотрим на переменные, которые содержит датасет:
#
# 1 school — аббревиатура школы, в которой учится ученик
#
# 2 sex — пол ученика ('F' - женский, 'M' - мужской)
#
# 3 age — возраст ученика (от 15 до 22)
#
# 4 address — тип адреса ученика ('U' - городской, 'R' - за городом)
#
# 5 famsize — размер семьи('LE3' <= 3, 'GT3' >3)
#
# 6 Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)
#
# 7 Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
#
# 8 Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
#
# 9 Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
#
# 10 Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
#
# 11 reason — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)
#
# 12 guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
#
# 13 traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)
#
# 14 studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
#
# 15 failures — количество внеучебных неудач (n, если 1<=n<=3, иначе 0)
#
# 16 schoolsup — дополнительная образовательная поддержка (yes или no)
#
# 17 famsup — семейная образовательная поддержка (yes или no)
#
# 18 paid — дополнительные платные занятия по математике (yes или no)
#
# 19 activities — дополнительные внеучебные занятия (yes или no)
#
# 20 nursery — посещал детский сад (yes или no)
#
# 21 higher — хочет получить высшее образование (yes или no)
#
# 22 internet — наличие интернета дома (yes или no)
#
# 23 romantic — в романтических отношениях (yes или no)
#
# 24 famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
#
# 25 freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)
#
# 26 goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
#
# 27 health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
#
# 28 absences — количество пропущенных занятий
#
# 29 score — баллы по госэкзамену по математике
#
# Рекомендации по выполнению проекта
#
#     - Проведите первичную обработку данных. Так как данных много, стоит написать функции, которые можно применять к столбцам определённого типа. (провёл в ручную, потому что интересно)
#     - Посмотрите на распределение признака для числовых переменных, устраните выбросы.
#     - Оцените количество уникальных значений для номинативных переменных.
#     - По необходимости преобразуйте данные
#     - Проведите корреляционный анализ количественных переменных
#     - Отберите не коррелирующие переменные.
#     - Проанализируйте номинативные переменные и устраните те, которые не влияют на предсказываемую величину (в нашем случае — на переменную score).
#     - Не забудьте сформулировать выводы относительно качества данных и тех переменных, которые вы будете использовать в дальнейшем построении модели.

# %% [markdown]
# Ноутбук с решением должен содержать:
#
# → цели и задачи проекта;
#
# → поэтапное описание работы;
#
# → промежуточные выводы;
#
# → основные итоги работы.
#
# *Дополнительно: оставьте комментарий по своей работе для ментора.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind


pd.set_option('display.max_rows', 50) # показывать больше строк
pd.set_option('display.max_columns', 50) # показывать больше колонок

math = pd.read_csv('stud_math.csv')

import warnings
warnings.filterwarnings("ignore")

# %%
# переименую столбец 'studytime, granular'

math.columns = ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'studytime_granular', 'higher', 'internet', 'romantic', 'famrel',
       'freetime', 'goout', 'health', 'absences', 'score']

# %%
math.head() # посмотрю на данные
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0  at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0  at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0  at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0   health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0    other    other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother         2.0        2.0       0.0       yes     no   no
# 1  course   father         1.0        2.0       0.0        no    yes   no
# 2   other   mother         1.0        2.0       3.0       yes     no  NaN
# 3    home   mother         1.0        3.0       0.0        no    yes  yes
# 4    home   father         1.0        2.0       0.0        no    yes  yes
#
#   activities nursery  studytime_granular higher internet romantic  famrel  \
# 0         no     yes                -6.0    yes      NaN       no     4.0
# 1         no      no                -6.0    yes      yes       no     5.0
# 2         no     yes                -6.0    yes      yes      NaN     4.0
# 3        yes     yes                -9.0    yes      yes      yes     3.0
# 4         no     yes                -6.0    yes       no       no     4.0
#
#    freetime  goout  health  absences  score
# 0       3.0    4.0     3.0       6.0   30.0
# 1       3.0    3.0     3.0       4.0   30.0
# 2       3.0    2.0     3.0      10.0   50.0
# 3       2.0    2.0     5.0       2.0   75.0
# 4       3.0    2.0     5.0       4.0   50.0

# %%
math.info() # посмотрю на данные ещё раз
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   school              395 non-null    object
#  1   sex                 395 non-null    object
#  2   age                 395 non-null    int64
#  3   address             378 non-null    object
#  4   famsize             368 non-null    object
#  5   Pstatus             350 non-null    object
#  6   Medu                392 non-null    float64
#  7   Fedu                371 non-null    float64
#  8   Mjob                376 non-null    object
#  9   Fjob                359 non-null    object
#  10  reason              378 non-null    object
#  11  guardian            364 non-null    object
#  12  traveltime          367 non-null    float64
#  13  studytime           388 non-null    float64
#  14  failures            373 non-null    float64
#  15  schoolsup           386 non-null    object
#  16  famsup              356 non-null    object
#  17  paid                355 non-null    object
#  18  activities          381 non-null    object
#  19  nursery             379 non-null    object
#  20  studytime_granular  388 non-null    float64
#  21  higher              375 non-null    object
#  22  internet            361 non-null    object
#  23  romantic            364 non-null    object
#  24  famrel              368 non-null    float64
#  25  freetime            384 non-null    float64
#  26  goout               387 non-null    float64
#  27  health              380 non-null    float64
#  28  absences            383 non-null    float64
#  29  score               389 non-null    float64
# dtypes: float64(12), int64(1), object(17)
# memory usage: 92.7+ KB

# %% [markdown]
# В датасете 395 строк, 13 числовых и 17 строковых столбцов.
#
# 27 столбцов имеют пропуски.

# %% [markdown]
# Теперь рассмотрим все столбцы по отдельности.

# %% [markdown]
# ## school
#
# столбец без пропусков
#
# В нашем датасете всего две школы, большенство учеников из GP. преобразовывать нечего.
#
# большенство учеников из школы GP живет в городе, а большенство учеников из школы MS живет загородом (пригодится для столбца adress).

# %%
math.school.value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
math[math.school == 'GP'].address.value_counts() #большенство учеников из школы GP живет в городе
# Out:
# U    277
# R     60
# Name: address, dtype: int64

# %%
math[math.school == 'MS'].address.value_counts() #большенство учеников из школы MS живет загородом
# Out:
# R    23
# U    18
# Name: address, dtype: int64

# %% [markdown]
# ## sex
#
# столбец без пропусков
#
# девочек немного больше. преобразовывать нечего.

# %%
math.sex.value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %% [markdown]
# ## age
#
# столбец без пропусков.
#
# школьников-нетинэйджеров - 5. по заданию стоит оставить все значения.

# %%
math.age.value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %% [markdown]
# ## address
#
# 378 non-null - 17 пропусков; 'U' - городской, 'R' - за городом
#
# некоторые пропущенные значения в адресе можно восстановить с помощью колонки 'reason' (причина выбора школы) и ответа в ней 'home' (близость к дому). ученикам, которые учатся в MS и имеют пропуск в колонке адрес присвою адрес R. всем остальным - присвою моду (U).

# %%
math.address.value_counts()
# Out:
# U    295
# R     83
# Name: address, dtype: int64

# %%
# заменю пропуски на none
math.address = math.address.fillna('none')

# найду искомые индексы
MS = math[(math.school == 'MS') & (math.address == 'none') & (math.reason == 'home')].index

# произведу подстановку значений
math.address[MS] = 'R'

# %%
# найду искомые индексы
U = math[(math.address == 'none')].index

# произведу подстановку значений
math.address[U] = 'U'

# %% [markdown]
# ## famsize
#
# 368 non-null
#
# 'LE3' <= 3, 'GT3' >3
#
# пропущенные значения заполню модой (GT3)

# %%
math.famsize.value_counts()
# Out:
# GT3    261
# LE3    107
# Name: famsize, dtype: int64

# %%
# произведу подстановку значений
math.famsize = math.famsize.fillna('GT3')

# %% [markdown]
# ## Pstatus
#
# 350 non-null
#
# 'T' - живут вместе 'A' - раздельно
#
# пропущенные значения заполню модой (T)

# %%
math.Pstatus.value_counts()
# Out:
# T    314
# A     36
# Name: Pstatus, dtype: int64

# %%
# произведу подстановку значений
math.Pstatus = math.Pstatus.fillna('T')

# %% [markdown]
# ## Medu
#
# 392 non-null есть три пропуска.
#
# 0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее
#
# заполню пропуски модой (4).

# %%
math.Medu.hist()

# %%
# произведу подстановку значений
math.Medu = math.Medu.fillna(4)

# %% [markdown]
# ## Fedu
#
# 371 non-null
#
# 0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее
#
# есть один выброс со значением 40. опечаткой может быть 4 или 0. исправлю на 4.
#
# заполню пропуски модой (2)

# %%
# найду индекс строки с опечаткой
mistake = math[math.Fedu == 40].index

# исправлю опечатку
math.Fedu[mistake] = 4

# %%
math.Fedu.hist()
math.Fedu.value_counts()
# Out:
# 2.0    106
# 3.0     96
# 4.0     89
# 1.0     78
# 0.0      2
# Name: Fedu, dtype: int64

# %%
# произведу подстановку значений
math.Fedu = math.Fedu.fillna(2)

# %% [markdown]
# ## Mjob
#
# 'teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба,'at_home' - не работает, 'other' - другое
#
# #376 non-null
#
# заполню пропуски модой (other)

# %%
math.Mjob.hist()
math.Mjob.value_counts()
# Out:
# other       133
# services     98
# at_home      58
# teacher      55
# health       32
# Name: Mjob, dtype: int64

# %%
# произведу подстановку значений
math.Mjob = math.Mjob.fillna('other')

# %% [markdown]
# ## Fjob
#
# 'teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое
#
# 359 non-null
#
# заполню пропуски модой (other)

# %%
math.Fjob.hist()
math.Fjob.value_counts()
# Out:
# other       197
# services    102
# teacher      29
# at_home      16
# health       15
# Name: Fjob, dtype: int64

# %%
# произведу подстановку
math.Fjob = math.Fjob.fillna('other')

# %% [markdown]
# ## reason
#
# 378 non-null
#
# 'home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое
#
# заполню пропуски модой (course)

# %%
math.reason.value_counts()
# Out:
# course        137
# home          104
# reputation    103
# other          34
# Name: reason, dtype: int64

# %%
# произведу подстановку
math.reason = math.reason.fillna('course')

# %% [markdown]
# ## guardian
#
# 364 non-null
#
# заполню пропуски модой (mother)

# %%
math.guardian.value_counts()
# Out:
# mother    250
# father     86
# other      28
# Name: guardian, dtype: int64

# %%
# произведу подстановку
math.guardian = math.guardian.fillna('mother')

# %% [markdown]
# ## traveltime
#
# 1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.
#
# 367 non-null
#
# заполню пропуски модой (1)

# %%
math.traveltime.value_counts()
# Out:
# 1.0    242
# 2.0     96
# 3.0     22
# 4.0      7
# Name: traveltime, dtype: int64

# %%
# произведу подстановку
math.traveltime = math.traveltime.fillna(1)

# %% [markdown]
# ## studytime
#
# время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
#
# 388 non-null
#
# заполню пропуски модой (2)

# %%
math.studytime.value_counts()
# Out:
# 2.0    194
# 1.0    103
# 3.0     64
# 4.0     27
# Name: studytime, dtype: int64

# %%
# произведу подстановку
math.studytime = math.studytime.fillna(2)

# %% [markdown]
# ## failures
#
# количество внеучебных неудач (n, если 1<=n<=3, иначе 0)
#
# 373 non-null
#
# заполню пропуски модой (0)

# %%
math.failures.value_counts()
# Out:
# 0.0    293
# 1.0     49
# 2.0     16
# 3.0     15
# Name: failures, dtype: int64

# %%
# произведу подстановку
math.failures = math.failures.fillna(0)

# %% [markdown]
# ## schoolsup
#
# дополнительная образовательная поддержка (yes или no)
#
# 386 non-null
#
# заполню пропуски модой (no)

# %%
math.schoolsup.hist()

# %%
# произведу подстановку
math.schoolsup = math.schoolsup.fillna('no')

# %% [markdown]
# ## famsup
#
# семейная образовательная поддержка (yes или no)
#
# 356 non-null
#
# пропуски заполню следующим образом:
#
#     если семейные отношения плохие (1 или 2), то нет семейной обр. поддержки и наоборот;
#     все остальные значения заполню модой (yes).

# %%
math.famsup.hist()
math.famsup.value_counts()
# Out:
# yes    219
# no     137
# Name: famsup, dtype: int64

# %%
# заменю пропуски на none
math.famsup = math.famsup.fillna('none')

# найду искомые индексы для 'no'
n = math[(math.famsup == 'none') & (math.famrel == 1)
          | (math.famsup == 'none') & (math.famrel == 2)].index

# произведу подстановку значений
math.famsup[n] = 'no'

# %%
# найду искомые индексы для 'yes'
y = math[(math.famsup == 'none')].index

# произведу подстановку значений
math.famsup[y] = 'yes'

# %% [markdown]
# ## paid
#
# дополнительные платные занятия по математике (yes или no)
#
# 355 non-null
#
#    пропушенные значения заполню следующим образом:
#
#     если ученик хочет получить высшее образование, то он берёт доп платные занятия по математике.
#     если не хочет, то не берёт доп занятия.
#     если пропушенны оба значения - заполню модой (no).

# %%
math.paid.hist()
math.paid.value_counts()
# Out:
# no     200
# yes    155
# Name: paid, dtype: int64

# %%
# заменю пропуски на none
math.higher = math.higher.fillna('none')
math.paid = math.paid.fillna('none')

# индексы для 'no'
n1 = math[(math.paid == 'none') & (math.higher != 'yes')].index

# индексы для 'yes'
y1 = math[(math.paid == 'none') & (math.higher == 'yes')].index

# %%
# произведу подстановку значений
math.paid[n1] = 'no'
math.paid[y1] = 'yes'

# %% [markdown]
# ## activities
#
# дополнительные внеучебные занятия (yes или no)
#
# 381 non-null
#
# заполню пропуски модой (yes)

# %%
math.activities.hist()
math.activities.value_counts()
# Out:
# yes    195
# no     186
# Name: activities, dtype: int64

# %%
# произведу подстановку
math.activities = math.activities.fillna('yes')

# %% [markdown]
# ## nursery
#
# посещал детский сад (yes или no)
#
# 379 non-null
#
# заполню пропуски модой (yes)

# %%
math.nursery.hist()
math.nursery.value_counts()
# Out:
# yes    300
# no      79
# Name: nursery, dtype: int64

# %%
# произведу подстановку
math.nursery = math.nursery.fillna('yes')

# %% [markdown]
# ## studytime_granular
#
# 388 non-null
#
# здесь дублируются значения столбца studytime умноженные на -3.
# из дальнейшего анлиза можно исключить.

# %%
math.studytime_granular.value_counts(), math.studytime.value_counts()
# Out:
# (-6.0     194
#  -3.0     103
#  -9.0      64
#  -12.0     27
#  Name: studytime_granular, dtype: int64,
#  2.0    201
#  1.0    103
#  3.0     64
#  4.0     27
#  Name: studytime, dtype: int64)

# %%
math.drop(['studytime_granular'], inplace = True, axis = 1) # исключу столбец

# %% [markdown]
# ## higher
#
# хочет получить высшее образование (yes или no)
#
# 375 non-null
#
# пропушенные значения заполню модой (yes)

# %%
math.higher.hist()
math.higher.value_counts()
# Out:
# yes     356
# none     20
# no       19
# Name: higher, dtype: int64

# %%
# индексы для 'yes'
y2 = math[math.higher == 'none'].index

# произведу подстановку значений
math.higher[y2] = 'yes'

# %% [markdown]
# ## internet
#
# наличие интернета дома (yes или no)
#
# 361 non-null.
#
# пропуски заполню модой (yes)

# %%
math.internet.hist()
math.internet.value_counts()
# Out:
# yes    305
# no      56
# Name: internet, dtype: int64

# %%
# пропуски заполню модой (yes)
math.internet = math.internet.fillna('yes')

# %% [markdown]
# ## romantic
#
# в романтических отношениях (yes или no)
#
# 364 non-null.
#
# пропуски заполню модой (no)

# %%
math.romantic.hist()
math.romantic.value_counts()
# Out:
# no     240
# yes    124
# Name: romantic, dtype: int64

# %%
# пропуски заполню модой (no)
math.romantic = math.romantic.fillna('no')

# %% [markdown]
# ## famrel
#
# семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
#
# 368 non-null
#
# есть выброс (-1), вероятнее всего это ошибка при вводе, изменю на 1.
#
# пропущенные значения заполню модой (4)

# %%
# найду индекс строки с опечаткой
mistake1 = math[math.famrel == -1].index

# исправлю опечатку
math.famrel[mistake1] = 1

# %%
math.famrel.hist()
math.famrel.value_counts()
# Out:
# 4.0    182
# 5.0     99
# 3.0     62
# 2.0     17
# 1.0      8
# Name: famrel, dtype: int64

# %%
math.famrel.describe()
# Out:
# count    368.000000
# mean       3.942935
# std        0.903824
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64

# %%
# пропуски заполню модой (4)
math.famrel = math.famrel.fillna(4)

# %% [markdown]
# ## freetime
#
# свободное время после школы (от 1 - очень мало до 5 - очень мого)
#
# 384 non-null
#
# нет возможности угадать пропуски, заполню их модой (3)

# %%
math.freetime.hist()
math.freetime.value_counts()
# Out:
# 3.0    153
# 4.0    112
# 2.0     63
# 5.0     38
# 1.0     18
# Name: freetime, dtype: int64

# %%
math.freetime.describe()
# Out:
# count    384.000000
# mean       3.231771
# std        0.993940
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: freetime, dtype: float64

# %%
# пропуски заполню модой (3)
math.freetime = math.freetime.fillna(3)

# %% [markdown]
# ## goout
#
# проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
#
# 387 non-null
#
# пропуски заполню модой (3)

# %%
math.goout.hist()
math.goout.value_counts()
# Out:
# 3.0    127
# 2.0    101
# 4.0     84
# 5.0     52
# 1.0     23
# Name: goout, dtype: int64

# %%
# пропуски заполню модой (3)
math.goout = math.goout.fillna(3)

# %% [markdown]
# ## health
#
# текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
#
# 380 non-null
#
# нет возможности угадать пропущенные значения в столбце, пропуски заполню модой (5)

# %%
math.health.hist()
math.health.value_counts()
# Out:
# 5.0    138
# 3.0     89
# 4.0     63
# 1.0     47
# 2.0     43
# Name: health, dtype: int64

# %%
# пропуски заполню модой (5)
math.health = math.health.fillna(5)

# %% [markdown]
# ## absences
#
# количество пропущенных занятий
#
# 383 non-null, 12 пропусков
#
# пропуски заполню медианным значением (4).
#
# не известно сколько всего занятий. есть значительные выбросы: *212* и *385* занятий. удалю их.

# %%
# пропуски заполню медианным значением (4)
math.absences = math.absences.fillna(4)

# %%
# избавлюсь от выбросов
math = math.loc[math.absences < 200]

# %%
math.absences.hist()

# %%
median = math.absences.median()
perc25 = math.absences.quantile(0.25)
perc75 = math.absences.quantile(0.75)
IQR = perc75 - perc25
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75)
      , "IQR: {}, ".format(IQR),"Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
math.absences.loc[math.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 15
                                                                                              , range = (0, 30), 
                                                                                             label = 'IQR')
math.absences.hist(alpha = 0.5, bins = 15, range = (0, 30),
                                                        label = 'Все значения до 30')
plt.legend()
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, 20.0].

# %% [markdown]
# ## score
#
# баллы по госэкзамену по математике
#
# 389 non-null, 6 пропусков, заменю их на медианное значение (55)
#
# есть выбросы со значением 0 - 37 учеников.
#
# Удалю выбросы.
#
# в остальном распределение похоже на бимодальное смещённое влево.

# %%
math.score.hist()
math.score.value_counts()
# Out:
# 50.0     54
# 55.0     46
# 0.0      37
# 75.0     33
# 65.0     31
# 40.0     31
# 60.0     31
# 70.0     27
# 45.0     26
# 80.0     16
# 30.0     15
# 90.0     12
# 35.0      9
# 25.0      7
# 85.0      5
# 95.0      5
# 100.0     1
# 20.0      1
# Name: score, dtype: int64

# %%
math.score.describe()
# Out:
# count    387.000000
# mean      52.196382
# std       22.914748
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %%
# пропуски заполню медианным значением (55)
math.score = math.score.fillna(55)

# %%
# избавлюсь от выбросов
math = math.loc[math.score != 0]

# %%
math.score.hist()

# %%
math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356 entries, 0 to 394
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      356 non-null    object
#  1   sex         356 non-null    object
#  2   age         356 non-null    int64
#  3   address     356 non-null    object
#  4   famsize     356 non-null    object
#  5   Pstatus     356 non-null    object
#  6   Medu        356 non-null    float64
#  7   Fedu        356 non-null    float64
#  8   Mjob        356 non-null    object
#  9   Fjob        356 non-null    object
#  10  reason      356 non-null    object
#  11  guardian    356 non-null    object
#  12  traveltime  356 non-null    float64
#  13  studytime   356 non-null    float64
#  14  failures    356 non-null    float64
#  15  schoolsup   356 non-null    object
#  16  famsup      356 non-null    object
#  17  paid        356 non-null    object
#  18  activities  356 non-null    object
#  19  nursery     356 non-null    object
#  20  higher      356 non-null    object
#  21  internet    356 non-null    object
#  22  romantic    356 non-null    object
#  23  famrel      356 non-null    float64
#  24  freetime    356 non-null    float64
#  25  goout       356 non-null    float64
#  26  health      356 non-null    float64
#  27  absences    356 non-null    float64
#  28  score       356 non-null    float64
# dtypes: float64(11), int64(1), object(17)
# memory usage: 83.4+ KB

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

math
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3       T   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health     other
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# 5       GP   M   16       U     LE3       T   4.0   3.0  services     other
# 6       GP   M   16       U     LE3       T   2.0   2.0     other     other
# 7       GP   F   17       U     GT3       A   4.0   4.0     other   teacher
# 8       GP   M   15       U     LE3       A   3.0   2.0  services     other
# 9       GP   M   15       U     GT3       T   3.0   4.0     other     other
# 10      GP   F   15       U     GT3       T   4.0   4.0   teacher    health
# 11      GP   F   15       U     GT3       T   2.0   4.0  services     other
# 12      GP   M   15       U     LE3       T   4.0   4.0    health  services
# 13      GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 14      GP   M   15       U     GT3       A   2.0   2.0     other     other
# 15      GP   F   16       U     GT3       T   4.0   4.0    health     other
# 16      GP   F   16       U     GT3       T   4.0   4.0  services  services
# 17      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 18      GP   M   17       U     GT3       T   3.0   2.0  services  services
# 19      GP   M   16       U     LE3       T   4.0   3.0    health     other
# 20      GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 21      GP   M   15       U     GT3       T   4.0   2.0    health    health
# 22      GP   M   16       U     LE3       T   4.0   2.0   teacher     other
# 23      GP   M   16       U     LE3       T   2.0   2.0     other     other
# 24      GP   F   15       R     GT3       T   2.0   4.0  services    health
# 25      GP   F   16       U     GT3       T   2.0   2.0  services  services
# 26      GP   M   15       U     GT3       T   2.0   2.0     other     other
# 27      GP   M   15       U     GT3       T   4.0   2.0    health  services
# 28      GP   M   16       U     LE3       T   3.0   4.0  services     other
# 29      GP   M   16       U     GT3       T   4.0   4.0     other   teacher
# 30      GP   M   15       U     GT3       T   4.0   4.0    health  services
# 31      GP   M   15       U     GT3       T   4.0   4.0  services     other
# 32      GP   M   15       R     GT3       T   4.0   3.0   teacher   at_home
# 33      GP   M   15       U     LE3       T   3.0   3.0     other     other
# 34      GP   M   16       U     GT3       T   3.0   2.0     other     other
# 35      GP   F   15       U     GT3       T   2.0   3.0     other     other
# 36      GP   M   15       U     GT3       T   4.0   3.0   teacher  services
# 37      GP   M   16       R     GT3       A   4.0   4.0     other   teacher
# 38      GP   F   15       R     GT3       T   3.0   4.0  services    health
# 39      GP   F   15       R     GT3       T   2.0   2.0   at_home     other
# 40      GP   F   16       U     LE3       T   2.0   2.0     other     other
# 41      GP   M   15       U     LE3       T   4.0   4.0   teacher     other
# 42      GP   M   15       U     GT3       T   4.0   2.0  services   teacher
# 43      GP   M   15       U     GT3       T   2.0   2.0  services  services
# 44      GP   F   16       U     LE3       T   2.0   2.0     other     other
# 45      GP   F   15       U     LE3       A   4.0   3.0     other     other
# 46      GP   F   16       U     LE3       A   3.0   2.0     other  services
# 47      GP   M   16       U     GT3       T   4.0   3.0    health     other
# 48      GP   M   15       U     GT3       T   4.0   2.0   teacher     other
# 49      GP   F   15       U     GT3       T   4.0   4.0  services   teacher
# 50      GP   F   16       U     LE3       T   2.0   2.0  services  services
# 51      GP   F   15       U     LE3       T   4.0   2.0    health     other
# 52      GP   M   15       U     LE3       A   4.0   2.0    health     other
# 53      GP   F   15       U     GT3       T   4.0   4.0  services  services
# 54      GP   F   15       U     LE3       T   3.0   3.0     other     other
# 55      GP   F   16       U     GT3       A   2.0   1.0     other     other
# 56      GP   F   15       U     GT3       A   4.0   3.0  services  services
# 57      GP   M   15       U     GT3       T   4.0   2.0   teacher    health
# 58      GP   M   15       U     LE3       T   1.0   2.0     other   at_home
# 59      GP   F   16       U     GT3       T   4.0   2.0     other     other
# 60      GP   F   16       R     GT3       T   4.0   4.0    health   teacher
# 61      GP   F   16       U     GT3       T   1.0   1.0  services  services
# 62      GP   F   16       U     LE3       T   1.0   2.0     other  services
# 63      GP   F   16       U     GT3       T   4.0   3.0   teacher    health
# 64      GP   F   15       U     LE3       T   4.0   3.0  services  services
# 65      GP   F   16       U     LE3       T   4.0   3.0   teacher  services
# 66      GP   M   15       U     GT3       A   4.0   4.0     other  services
# 67      GP   F   16       U     GT3       T   3.0   2.0  services     other
# 68      GP   F   15       R     LE3       T   2.0   2.0    health     other
# 69      GP   F   15       R     LE3       T   3.0   1.0     other     other
# 70      GP   M   16       U     GT3       T   3.0   1.0     other     other
# 71      GP   M   15       U     GT3       T   4.0   2.0     other     other
# 72      GP   F   15       R     GT3       T   1.0   1.0     other     other
# 73      GP   M   16       U     GT3       T   3.0   1.0     other     other
# 74      GP   F   16       U     GT3       T   3.0   3.0     other  services
# 75      GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 76      GP   M   15       U     GT3       T   4.0   0.0   teacher     other
# 77      GP   F   16       U     GT3       T   2.0   2.0     other     other
# 78      GP   M   17       U     GT3       T   2.0   1.0     other     other
# 79      GP   F   16       U     GT3       T   3.0   4.0   at_home     other
# 80      GP   M   15       U     GT3       T   2.0   3.0     other  services
# 81      GP   M   15       U     GT3       T   2.0   3.0     other     other
# 82      GP   F   15       U     LE3       T   3.0   2.0  services     other
# 83      GP   M   15       U     LE3       T   2.0   2.0  services  services
# 84      GP   F   15       U     GT3       T   1.0   1.0     other     other
# 85      GP   F   15       U     GT3       T   4.0   4.0  services  services
# 86      GP   F   16       U     LE3       T   2.0   2.0   at_home     other
# 87      GP   F   15       U     GT3       T   4.0   2.0     other     other
# 88      GP   M   16       U     GT3       T   2.0   2.0     other     other
# 89      GP   M   16       U     LE3       A   4.0   4.0   teacher    health
# 90      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 91      GP   F   15       U     GT3       T   4.0   3.0  services     other
# 92      GP   F   16       U     LE3       T   4.0   1.0     other     other
# 93      GP   F   16       U     GT3       T   4.0   2.0   teacher  services
# 94      GP   M   15       U     LE3       T   2.0   2.0  services    health
# 95      GP   F   15       R     GT3       T   1.0   1.0   at_home     other
# 96      GP   M   16       U     GT3       T   4.0   3.0  services     other
# 97      GP   F   16       U     GT3       T   2.0   1.0     other     other
# 98      GP   F   16       U     GT3       T   4.0   4.0     other     other
# 99      GP   F   16       U     GT3       T   4.0   3.0     other   at_home
# 100     GP   M   16       U     GT3       T   4.0   4.0  services  services
# 101     GP   M   16       U     GT3       T   4.0   4.0  services   teacher
# 102     GP   M   15       U     GT3       T   4.0   4.0  services     other
# 103     GP   F   15       U     GT3       T   3.0   2.0  services     other
# 104     GP   M   15       U     GT3       A   3.0   4.0     other     other
# 105     GP   F   15       U     GT3       A   3.0   3.0     other    health
# 106     GP   F   15       U     GT3       T   2.0   2.0     other     other
# 107     GP   M   16       U     GT3       T   3.0   3.0  services     other
# 108     GP   M   15       R     GT3       T   4.0   4.0     other     other
# 109     GP   F   16       U     LE3       T   4.0   4.0    health    health
# 110     GP   M   15       U     LE3       A   4.0   4.0   teacher   teacher
# 111     GP   F   16       R     GT3       T   3.0   3.0  services     other
# 112     GP   F   16       U     GT3       T   2.0   2.0   at_home     other
# 113     GP   M   15       U     LE3       T   4.0   2.0   teacher     other
# 114     GP   M   15       R     GT3       T   2.0   1.0    health  services
# 115     GP   M   16       U     GT3       T   4.0   4.0   teacher   teacher
# 116     GP   M   15       U     GT3       T   4.0   4.0     other   teacher
# 117     GP   M   16       U     GT3       T   3.0   3.0     other  services
# 118     GP   M   17       R     GT3       T   1.0   3.0     other     other
# 119     GP   M   15       U     GT3       T   3.0   4.0     other     other
# 120     GP   F   15       U     GT3       T   1.0   2.0   at_home     other
# 121     GP   M   15       U     GT3       T   2.0   2.0  services  services
# 122     GP   F   16       U     LE3       T   2.0   4.0     other    health
# 123     GP   M   16       U     GT3       T   4.0   4.0    health     other
# 124     GP   F   16       U     GT3       T   2.0   2.0     other     other
# 125     GP   M   15       U     GT3       T   3.0   4.0  services  services
# 126     GP   F   15       U     LE3       A   3.0   4.0     other     other
# 127     GP   F   19       U     GT3       T   0.0   1.0   at_home     other
# 129     GP   M   16       R     GT3       T   4.0   4.0   teacher   teacher
# 132     GP   F   17       U     LE3       T   2.0   2.0     other     other
# 133     GP   F   16       U     GT3       A   3.0   4.0  services     other
# 138     GP   M   16       U     LE3       T   1.0   1.0  services     other
# 139     GP   F   15       U     GT3       T   4.0   4.0   teacher   teacher
# 141     GP   M   16       U     LE3       T   2.0   2.0  services  services
# 142     GP   F   15       U     GT3       T   4.0   2.0   teacher  services
# 143     GP   F   16       U     LE3       T   1.0   1.0   at_home   at_home
# 145     GP   F   15       U     GT3       T   1.0   1.0     other  services
# 147     GP   F   15       U     GT3       T   1.0   2.0   at_home     other
# 149     GP   M   15       U     LE3       T   2.0   1.0  services     other
# 151     GP   M   16       U     LE3       T   2.0   1.0   at_home     other
# 152     GP   F   15       R     GT3       T   3.0   3.0  services     other
# 154     GP   F   17       U     GT3       T   4.0   4.0     other   teacher
# 155     GP   M   15       R     GT3       T   2.0   3.0   at_home  services
# 156     GP   M   17       R     LE3       T   1.0   2.0     other     other
# 157     GP   F   18       R     GT3       T   1.0   1.0   at_home     other
# 158     GP   M   16       R     GT3       T   2.0   2.0   at_home     other
# 159     GP   M   16       U     GT3       T   3.0   2.0     other  services
# 161     GP   M   15       R     GT3       T   3.0   2.0     other     other
# 163     GP   M   17       U     GT3       T   1.0   3.0   at_home  services
# 164     GP   M   17       R     LE3       T   1.0   1.0     other  services
# 165     GP   M   16       U     GT3       T   3.0   2.0  services  services
# 166     GP   M   16       U     GT3       T   2.0   2.0     other     other
# 167     GP   F   16       U     GT3       T   4.0   2.0    health  services
# 169     GP   F   16       U     GT3       T   4.0   4.0    health     other
# 171     GP   M   16       U     GT3       T   1.0   0.0     other     other
# 172     GP   M   17       U     GT3       T   4.0   4.0   teacher     other
# 174     GP   F   16       U     LE3       T   3.0   3.0     other     other
# 175     GP   M   17       U     LE3       T   4.0   3.0   teacher     other
# 176     GP   F   16       U     GT3       T   2.0   2.0  services     other
# 177     GP   M   17       U     GT3       T   3.0   3.0     other     other
# 178     GP   M   16       R     GT3       T   4.0   2.0   teacher  services
# 179     GP   M   17       U     GT3       T   4.0   3.0     other     other
# 180     GP   M   16       U     GT3       T   4.0   2.0   teacher     other
# 181     GP   M   16       U     GT3       T   3.0   3.0  services     other
# 182     GP   F   17       U     GT3       T   2.0   4.0  services     other
# 183     GP   F   17       U     LE3       T   3.0   3.0     other     other
# 184     GP   F   16       U     GT3       T   3.0   2.0     other     other
# 185     GP   M   17       U     GT3       T   3.0   3.0  services  services
# 186     GP   M   16       U     GT3       T   1.0   2.0  services  services
# 187     GP   M   16       U     LE3       T   2.0   1.0     other     other
# 188     GP   F   17       U     GT3       A   3.0   3.0    health     other
# 189     GP   M   17       R     GT3       T   1.0   2.0   at_home     other
# 190     GP   F   16       U     GT3       T   2.0   3.0  services  services
# 191     GP   F   17       U     GT3       T   1.0   1.0   at_home  services
# 192     GP   M   17       U     GT3       T   1.0   2.0   at_home  services
# 193     GP   M   16       R     GT3       T   4.0   3.0  services  services
# 194     GP   M   16       U     GT3       T   2.0   3.0     other     other
# 195     GP   F   17       U     GT3       T   2.0   2.0  services  services
# 196     GP   M   17       U     GT3       T   4.0   4.0  services   teacher
# 197     GP   M   16       R     LE3       T   3.0   3.0   teacher     other
# 198     GP   F   17       U     GT3       T   4.0   4.0  services   teacher
# 199     GP   F   16       U     LE3       T   4.0   4.0   teacher   teacher
# 200     GP   F   16       U     GT3       T   4.0   3.0    health     other
# 201     GP   F   16       U     GT3       T   2.0   3.0     other     other
# 202     GP   F   17       U     GT3       T   1.0   1.0     other     other
# 203     GP   F   17       R     GT3       T   2.0   2.0     other     other
# 204     GP   F   16       R     GT3       T   2.0   2.0  services  services
# 205     GP   F   17       U     GT3       T   3.0   4.0   at_home  services
# 206     GP   F   16       U     GT3       A   3.0   1.0  services     other
# 207     GP   F   16       U     GT3       T   4.0   3.0   teacher     other
# 208     GP   F   16       U     GT3       T   1.0   1.0   at_home     other
# 209     GP   F   17       R     GT3       T   4.0   3.0   teacher     other
# 210     GP   F   19       U     GT3       T   3.0   3.0     other     other
# 211     GP   M   17       U     LE3       T   4.0   4.0  services     other
# 212     GP   F   16       U     GT3       A   2.0   2.0     other     other
# 213     GP   M   18       U     GT3       T   2.0   2.0  services     other
# 214     GP   F   17       R     LE3       T   4.0   4.0  services     other
# 215     GP   F   17       U     LE3       T   3.0   2.0     other     other
# 216     GP   F   17       U     GT3       T   4.0   3.0     other     other
# 217     GP   M   18       U     LE3       T   3.0   3.0  services    health
# 218     GP   F   17       U     GT3       T   2.0   3.0   at_home     other
# 219     GP   F   17       U     GT3       T   2.0   2.0     other   at_home
# 220     GP   F   17       R     GT3       T   2.0   1.0   at_home  services
# 223     GP   M   18       U     GT3       T   2.0   2.0     other     other
# 224     GP   F   16       U     GT3       T   4.0   4.0     other  services
# 225     GP   F   18       R     GT3       T   3.0   1.0     other     other
# 226     GP   F   17       U     GT3       T   3.0   2.0     other     other
# 227     GP   M   17       U     LE3       T   2.0   3.0  services  services
# 228     GP   M   18       U     GT3       T   2.0   1.0   at_home     other
# 229     GP   F   17       U     GT3       A   2.0   1.0     other     other
# 230     GP   F   17       U     LE3       T   4.0   3.0    health     other
# 231     GP   M   17       R     GT3       T   2.0   2.0     other     other
# 232     GP   M   17       U     GT3       T   4.0   2.0   teacher   teacher
# 233     GP   M   16       U     GT3       T   4.0   4.0    health     other
# 234     GP   M   16       U     LE3       T   1.0   1.0     other     other
# 235     GP   M   16       U     GT3       T   3.0   2.0   at_home     other
# 236     GP   M   17       U     LE3       T   2.0   2.0     other     other
# 237     GP   F   16       U     GT3       T   2.0   1.0     other     other
# 238     GP   F   17       R     GT3       T   2.0   1.0   at_home  services
# 240     GP   M   17       U     LE3       T   4.0   3.0    health     other
# 241     GP   M   17       U     LE3       A   4.0   4.0   teacher     other
# 243     GP   M   16       U     GT3       T   4.0   4.0  services  services
# 244     GP   F   18       U     GT3       T   2.0   1.0     other     other
# 245     GP   M   16       U     GT3       T   2.0   1.0     other     other
# 246     GP   M   17       U     GT3       T   2.0   3.0     other     other
# 247     GP   M   22       U     GT3       T   3.0   1.0  services  services
# 248     GP   M   18       R     LE3       T   3.0   3.0     other  services
# 249     GP   M   16       U     GT3       T   0.0   2.0     other     other
# 250     GP   M   18       U     GT3       T   3.0   2.0  services     other
# 251     GP   M   16       U     GT3       T   3.0   3.0   at_home     other
# 252     GP   M   18       U     GT3       T   2.0   1.0  services  services
# 253     GP   M   16       R     GT3       T   2.0   1.0     other     other
# 254     GP   M   17       U     GT3       T   2.0   1.0     other     other
# 255     GP   M   17       U     LE3       T   1.0   1.0    health     other
# 256     GP   F   17       U     LE3       T   4.0   2.0   teacher  services
# 257     GP   M   19       U     LE3       A   4.0   3.0  services   at_home
# 258     GP   M   18       U     GT3       T   2.0   1.0     other     other
# 260     GP   F   18       U     GT3       T   4.0   3.0     other     other
# 261     GP   M   18       U     GT3       T   4.0   3.0   teacher     other
# 262     GP   M   18       R     GT3       T   3.0   2.0     other     other
# 263     GP   F   17       U     GT3       T   3.0   3.0     other     other
# 265     GP   M   18       R     LE3       T   3.0   4.0     other     other
# 266     GP   M   17       U     GT3       T   3.0   1.0  services     other
# 267     GP   F   18       R     GT3       T   4.0   4.0   teacher     other
# 268     GP   M   18       U     GT3       T   4.0   2.0     other     other
# 270     GP   F   19       U     GT3       T   3.0   3.0     other  services
# 271     GP   F   18       U     GT3       T   2.0   3.0     other  services
# 272     GP   F   18       U     LE3       T   1.0   1.0     other     other
# 273     GP   M   17       R     GT3       T   1.0   2.0   at_home   at_home
# 274     GP   F   17       U     GT3       T   2.0   4.0   at_home    health
# 275     GP   F   17       U     LE3       T   2.0   2.0  services     other
# 276     GP   F   18       R     GT3       A   3.0   2.0     other  services
# 277     GP   M   18       U     GT3       T   4.0   4.0     other  services
# 278     GP   F   18       U     GT3       T   4.0   4.0    health    health
# 279     GP   M   18       U     LE3       T   4.0   3.0   teacher  services
# 280     GP   M   17       U     GT3       A   4.0   2.0  services     other
# 281     GP   M   17       U     LE3       A   3.0   2.0   teacher  services
# 282     GP   F   18       R     LE3       T   1.0   1.0   at_home     other
# 283     GP   F   18       U     GT3       T   1.0   1.0     other     other
# 284     GP   F   17       U     GT3       T   2.0   2.0     other     other
# 285     GP   M   17       U     GT3       T   1.0   1.0     other     other
# 286     GP   F   18       U     GT3       T   2.0   2.0   at_home   at_home
# 287     GP   F   17       U     GT3       T   1.0   2.0  services   teacher
# 288     GP   M   18       U     GT3       T   2.0   1.0  services  services
# 289     GP   M   18       U     LE3       A   4.0   4.0   teacher   teacher
# 290     GP   M   18       U     GT3       T   4.0   2.0   teacher     other
# 291     GP   F   17       U     GT3       T   4.0   3.0     other  services
# 292     GP   F   18       U     LE3       T   2.0   1.0  services   at_home
# 293     GP   F   17       R     LE3       T   3.0   1.0  services     other
# 294     GP   M   18       R     LE3       T   3.0   2.0  services     other
# 295     GP   M   17       U     GT3       T   3.0   3.0    health     other
# 297     GP   F   18       U     LE3       T   4.0   3.0     other     other
# 298     GP   F   18       U     GT3       T   4.0   3.0     other     other
# 299     GP   M   18       U     LE3       T   4.0   4.0   teacher   teacher
# 300     GP   F   18       U     LE3       A   4.0   4.0    health     other
# 301     GP   M   17       U     LE3       T   4.0   4.0     other   teacher
# 302     GP   F   17       U     GT3       T   4.0   2.0     other     other
# 303     GP   F   17       U     GT3       T   3.0   2.0    health     other
# 304     GP   M   19       U     GT3       T   3.0   3.0     other     other
# 305     GP   F   18       U     GT3       T   2.0   4.0  services   at_home
# 306     GP   M   20       U     GT3       A   3.0   2.0  services     other
# 307     GP   M   19       U     GT3       T   4.0   4.0   teacher  services
# 308     GP   M   19       R     GT3       T   3.0   3.0     other  services
# 309     GP   F   19       U     LE3       T   1.0   1.0   at_home     other
# 311     GP   F   19       U     GT3       T   2.0   1.0   at_home     other
# 312     GP   M   19       U     GT3       T   1.0   2.0     other  services
# 313     GP   F   19       U     GT3       T   3.0   2.0  services     other
# 314     GP   F   19       U     GT3       T   1.0   1.0   at_home    health
# 315     GP   F   19       R     GT3       T   2.0   3.0     other     other
# 317     GP   F   18       U     GT3       T   4.0   3.0     other     other
# 318     GP   F   17       R     GT3       T   3.0   4.0   at_home  services
# 319     GP   F   18       U     GT3       T   4.0   4.0   teacher     other
# 320     GP   F   17       U     GT3       A   4.0   3.0  services  services
# 321     GP   F   17       U     GT3       T   2.0   2.0     other     other
# 322     GP   F   17       R     LE3       T   2.0   2.0  services  services
# 323     GP   F   17       U     GT3       T   3.0   1.0  services  services
# 324     GP   F   17       U     LE3       T   0.0   2.0   at_home   at_home
# 325     GP   M   18       U     GT3       T   4.0   4.0     other     other
# 326     GP   M   17       U     GT3       T   3.0   3.0     other  services
# 327     GP   M   17       R     GT3       T   2.0   2.0  services     other
# 328     GP   F   17       U     GT3       T   4.0   2.0   teacher  services
# 329     GP   F   17       U     GT3       T   4.0   4.0   teacher   teacher
# 330     GP   M   18       U     LE3       T   2.0   2.0     other     other
# 331     GP   F   17       R     GT3       T   2.0   4.0   at_home     other
# 335     GP   F   17       U     GT3       T   3.0   4.0  services     other
# 336     GP   F   19       R     GT3       A   3.0   1.0  services     other
# 338     GP   F   18       U     LE3       T   3.0   3.0  services  services
# 339     GP   F   17       R     GT3       A   3.0   2.0     other     other
# 340     GP   F   19       U     GT3       T   2.0   1.0  services  services
# 342     GP   M   18       U     LE3       T   3.0   4.0  services     other
# 344     GP   F   18       U     GT3       T   2.0   3.0   at_home     other
# 345     GP   F   18       U     GT3       T   3.0   2.0     other     other
# 346     GP   M   18       R     GT3       T   4.0   3.0   teacher  services
# 347     GP   M   18       U     GT3       T   4.0   3.0   teacher     other
# 348     GP   F   17       U     GT3       T   4.0   3.0    health     other
# 349     MS   M   18       R     GT3       T   3.0   2.0     other     other
# 350     MS   M   19       R     GT3       T   1.0   1.0     other  services
# 351     MS   M   17       U     GT3       T   3.0   3.0    health     other
# 352     MS   M   18       U     LE3       T   1.0   3.0   at_home  services
# 353     MS   M   19       R     GT3       T   1.0   1.0     other     other
# 354     MS   M   17       R     GT3       T   4.0   3.0  services     other
# 355     MS   F   18       U     GT3       T   3.0   3.0  services  services
# 356     MS   F   17       R     GT3       T   4.0   4.0   teacher  services
# 357     MS   F   17       U     LE3       T   3.0   2.0  services     other
# 358     MS   M   18       U     LE3       T   1.0   1.0     other  services
# 359     MS   F   18       U     LE3       T   1.0   1.0   at_home  services
# 360     MS   F   18       R     GT3       A   1.0   4.0   at_home     other
# 361     MS   M   18       R     LE3       T   1.0   1.0   at_home     other
# 362     MS   F   18       U     GT3       T   3.0   3.0  services  services
# 363     MS   F   17       U     LE3       T   4.0   4.0   at_home     other
# 364     MS   F   17       R     GT3       T   1.0   2.0     other  services
# 365     MS   M   18       R     GT3       T   1.0   3.0   at_home     other
# 366     MS   M   18       U     LE3       T   4.0   4.0   teacher  services
# 368     MS   F   18       U     GT3       T   2.0   3.0   at_home  services
# 369     MS   F   18       R     GT3       T   4.0   4.0     other   teacher
# 370     MS   F   19       U     LE3       T   3.0   2.0  services  services
# 371     MS   M   18       R     LE3       T   1.0   2.0   at_home  services
# 372     MS   F   17       R     GT3       T   2.0   2.0     other   at_home
# 373     MS   F   17       R     GT3       T   1.0   2.0     other     other
# 374     MS   F   18       R     LE3       T   4.0   2.0     other     other
# 375     MS   F   18       R     GT3       T   1.0   1.0     other     other
# 376     MS   F   20       U     GT3       T   4.0   2.0    health     other
# 377     MS   F   18       R     LE3       T   4.0   4.0   teacher  services
# 378     MS   F   18       U     GT3       T   3.0   3.0     other     other
# 379     MS   F   17       R     GT3       T   3.0   1.0   at_home     other
# 380     MS   M   18       U     GT3       T   4.0   4.0   teacher   teacher
# 381     MS   M   18       R     GT3       T   2.0   1.0     other     other
# 382     MS   M   17       U     GT3       T   2.0   3.0     other  services
# 384     MS   M   18       R     GT3       T   4.0   2.0     other     other
# 385     MS   F   18       R     GT3       T   2.0   2.0   at_home     other
# 386     MS   F   18       R     GT3       T   4.0   4.0   teacher   at_home
# 388     MS   F   18       U     LE3       T   3.0   1.0   teacher  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 392     MS   M   21       R     GT3       T   1.0   1.0     other     other
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 0        course   mother         2.0        2.0       0.0       yes     no
# 1        course   father         1.0        2.0       0.0        no    yes
# 2         other   mother         1.0        2.0       3.0       yes     no
# 3          home   mother         1.0        3.0       0.0        no    yes
# 4          home   father         1.0        2.0       0.0        no    yes
# 5    reputation   mother         1.0        2.0       0.0        no    yes
# 6          home   mother         1.0        2.0       0.0        no     no
# 7          home   mother         2.0        2.0       0.0       yes    yes
# 8          home   mother         1.0        2.0       0.0        no    yes
# 9          home   mother         1.0        2.0       0.0        no    yes
# 10   reputation   mother         1.0        2.0       0.0        no    yes
# 11   reputation   father         3.0        3.0       0.0        no    yes
# 12       course   father         1.0        1.0       0.0        no    yes
# 13       course   mother         2.0        2.0       0.0        no    yes
# 14         home    other         1.0        3.0       0.0        no    yes
# 15         home   mother         1.0        1.0       0.0        no    yes
# 16   reputation   mother         1.0        3.0       0.0        no    yes
# 17   reputation   mother         3.0        2.0       0.0       yes    yes
# 18       course   mother         1.0        1.0       3.0        no    yes
# 19         home   father         1.0        1.0       0.0        no     no
# 20   reputation   mother         1.0        2.0       0.0        no     no
# 21        other   father         1.0        1.0       0.0        no    yes
# 22       course   mother         1.0        2.0       0.0        no    yes
# 23   reputation   mother         2.0        2.0       0.0        no    yes
# 24       course   mother         1.0        3.0       0.0       yes    yes
# 25         home   mother         1.0        1.0       2.0        no    yes
# 26         home   mother         1.0        1.0       0.0        no    yes
# 27        other   mother         1.0        1.0       0.0        no     no
# 28         home   mother         1.0        2.0       0.0       yes    yes
# 29         home   mother         1.0        2.0       0.0        no    yes
# 30         home   mother         1.0        2.0       0.0        no    yes
# 31   reputation   mother         2.0        2.0       0.0        no    yes
# 32       course   mother         1.0        2.0       0.0        no    yes
# 33       course   mother         1.0        2.0       0.0        no    yes
# 34         home   mother         1.0        1.0       0.0        no    yes
# 35        other   father         1.0        1.0       0.0        no    yes
# 36         home   mother         1.0        3.0       0.0        no    yes
# 37   reputation   mother         1.0        3.0       0.0        no    yes
# 38       course   mother         1.0        3.0       0.0       yes    yes
# 39   reputation   mother         1.0        1.0       0.0       yes    yes
# 40         home   mother         2.0        2.0       1.0        no    yes
# 41         home   mother         1.0        1.0       0.0        no    yes
# 42       course   father         1.0        2.0       0.0        no    yes
# 43       course   father         1.0        1.0       0.0       yes    yes
# 44       course   father         2.0        2.0       1.0       yes     no
# 45       course   mother         1.0        2.0       0.0       yes    yes
# 46         home   mother         1.0        2.0       0.0        no    yes
# 47   reputation   mother         1.0        4.0       0.0        no     no
# 48         home   mother         1.0        2.0       0.0        no    yes
# 49        other   mother         1.0        2.0       1.0       yes    yes
# 50       course   mother         3.0        2.0       0.0        no    yes
# 51        other   mother         1.0        2.0       0.0        no    yes
# 52        other   father         2.0        1.0       1.0        no    yes
# 53       course   mother         1.0        1.0       0.0       yes    yes
# 54        other   mother         1.0        1.0       0.0        no     no
# 55        other   mother         1.0        2.0       0.0        no     no
# 56   reputation   mother         1.0        2.0       0.0        no    yes
# 57   reputation   mother         1.0        2.0       0.0        no    yes
# 58         home   father         1.0        2.0       0.0       yes    yes
# 59       course   mother         1.0        2.0       0.0        no    yes
# 60        other   mother         1.0        2.0       0.0        no    yes
# 61       course   father         4.0        1.0       0.0       yes    yes
# 62   reputation   father         1.0        2.0       0.0       yes     no
# 63       course   mother         1.0        3.0       0.0       yes    yes
# 64   reputation   father         1.0        2.0       0.0       yes     no
# 65       course   mother         3.0        2.0       0.0        no    yes
# 66   reputation   mother         1.0        4.0       0.0        no    yes
# 67       course   mother         1.0        4.0       0.0       yes    yes
# 68   reputation   mother         1.0        2.0       0.0       yes    yes
# 69   reputation   father         2.0        4.0       0.0        no    yes
# 70   reputation   father         1.0        4.0       0.0        no    yes
# 71       course   mother         1.0        4.0       0.0        no     no
# 72   reputation   mother         1.0        2.0       2.0       yes    yes
# 73       course   mother         1.0        1.0       0.0        no     no
# 74         home   mother         1.0        2.0       0.0       yes    yes
# 75         home   mother         1.0        2.0       0.0        no    yes
# 76       course   mother         2.0        4.0       0.0        no     no
# 77       course   mother         1.0        4.0       0.0        no     no
# 78         home   mother         2.0        1.0       3.0       yes    yes
# 79       course   mother         1.0        2.0       0.0        no    yes
# 80       course   father         1.0        1.0       0.0       yes    yes
# 81         home   mother         1.0        3.0       0.0       yes     no
# 82   reputation   mother         1.0        2.0       0.0        no    yes
# 83         home   mother         2.0        2.0       0.0        no     no
# 84         home   father         1.0        2.0       0.0        no    yes
# 85   reputation   father         2.0        2.0       2.0        no     no
# 86       course   mother         1.0        2.0       0.0        no    yes
# 87   reputation   mother         1.0        3.0       0.0        no    yes
# 88   reputation   father         2.0        2.0       1.0        no     no
# 89   reputation   mother         1.0        2.0       0.0        no    yes
# 90         home   mother         1.0        3.0       0.0        no    yes
# 91   reputation   mother         1.0        2.0       0.0        no     no
# 92         home   father         1.0        2.0       0.0       yes    yes
# 93         home   mother         2.0        2.0       0.0        no    yes
# 94   reputation   mother         1.0        4.0       0.0        no    yes
# 95         home   mother         2.0        4.0       1.0       yes    yes
# 96   reputation   mother         2.0        1.0       0.0       yes    yes
# 97       course   mother         1.0        2.0       0.0        no    yes
# 98   reputation   mother         1.0        1.0       0.0        no    yes
# 99       course   mother         1.0        3.0       0.0       yes    yes
# 100       other   mother         1.0        1.0       0.0       yes    yes
# 101       other   father         1.0        3.0       0.0        no    yes
# 102      course   mother         1.0        1.0       0.0        no    yes
# 103        home   mother         2.0        2.0       0.0       yes    yes
# 104      course   mother         1.0        2.0       0.0        no    yes
# 105  reputation   father         1.0        4.0       0.0       yes     no
# 106      course   mother         1.0        4.0       0.0       yes    yes
# 107        home   father         1.0        3.0       0.0        no    yes
# 108        home   father         4.0        4.0       0.0        no    yes
# 109       other   mother         1.0        3.0       0.0        no    yes
# 110      course   mother         1.0        1.0       0.0        no     no
# 111  reputation   father         1.0        3.0       1.0       yes    yes
# 112      course   mother         1.0        2.0       1.0       yes     no
# 113      course   mother         1.0        1.0       0.0        no     no
# 114  reputation   mother         1.0        2.0       0.0        no     no
# 115      course   father         1.0        2.0       0.0        no    yes
# 116  reputation   father         2.0        2.0       0.0        no    yes
# 117        home   father         2.0        1.0       0.0        no     no
# 118      course   father         3.0        2.0       1.0        no    yes
# 119  reputation   father         1.0        1.0       0.0        no     no
# 120      course   mother         1.0        2.0       0.0        no     no
# 121        home   father         1.0        4.0       0.0        no    yes
# 122      course   father         2.0        2.0       0.0        no    yes
# 123      course   mother         1.0        1.0       0.0        no    yes
# 124        home   mother         1.0        2.0       0.0        no     no
# 125        home   father         1.0        1.0       0.0       yes     no
# 126        home   mother         1.0        2.0       0.0       yes     no
# 127      course    other         1.0        2.0       3.0        no    yes
# 129      course   mother         1.0        2.0       0.0        no     no
# 132      course   father         1.0        1.0       0.0        no    yes
# 133      course   father         1.0        1.0       0.0        no     no
# 138      course   mother         1.0        2.0       1.0        no     no
# 139      course   mother         2.0        1.0       0.0        no     no
# 141  reputation   father         2.0        1.0       2.0        no    yes
# 142      course   mother         1.0        3.0       0.0        no    yes
# 143      course   mother         1.0        1.0       0.0        no     no
# 145      course   father         1.0        2.0       0.0        no    yes
# 147      course   mother         1.0        2.0       0.0        no    yes
# 149      course   mother         4.0        1.0       3.0        no    yes
# 151      course   mother         1.0        1.0       1.0        no     no
# 152  reputation    other         2.0        3.0       2.0        no    yes
# 154      course   mother         1.0        1.0       0.0       yes    yes
# 155      course   mother         1.0        2.0       0.0       yes     no
# 156  reputation   mother         1.0        1.0       0.0        no     no
# 157      course   mother         1.0        1.0       3.0        no    yes
# 158      course   mother         3.0        1.0       0.0        no     no
# 159      course   father         1.0        2.0       1.0        no    yes
# 161      course   mother         2.0        2.0       2.0       yes    yes
# 163      course   father         1.0        1.0       0.0        no     no
# 164      course   mother         4.0        2.0       3.0        no     no
# 165      course   mother         2.0        1.0       1.0        no    yes
# 166      course   father         1.0        2.0       0.0        no     no
# 167        home   father         1.0        2.0       0.0        no    yes
# 169  reputation   mother         1.0        2.0       0.0        no    yes
# 171  reputation   mother         2.0        2.0       0.0        no    yes
# 172  reputation   mother         1.0        2.0       0.0        no    yes
# 174  reputation   mother         2.0        2.0       0.0        no    yes
# 175      course   mother         2.0        2.0       0.0        no     no
# 176  reputation   mother         2.0        2.0       0.0        no     no
# 177  reputation   father         1.0        2.0       0.0        no     no
# 178       other   mother         1.0        1.0       0.0        no    yes
# 179      course   mother         1.0        2.0       0.0        no    yes
# 180        home   mother         1.0        2.0       0.0        no    yes
# 181        home   mother         1.0        2.0       0.0        no     no
# 182  reputation   father         1.0        2.0       0.0        no    yes
# 183  reputation   mother         1.0        2.0       0.0        no    yes
# 184  reputation   mother         1.0        2.0       0.0        no    yes
# 185      course   mother         1.0        2.0       0.0        no    yes
# 186      course   mother         1.0        1.0       0.0        no    yes
# 187      course   mother         1.0        2.0       0.0        no     no
# 188  reputation   mother         1.0        2.0       0.0        no    yes
# 189        home   mother         1.0        2.0       0.0        no     no
# 190      course   mother         1.0        2.0       0.0        no     no
# 191      course   mother         1.0        2.0       0.0        no     no
# 192       other    other         2.0        2.0       0.0        no     no
# 193  reputation   mother         1.0        1.0       0.0        no    yes
# 194        home   father         2.0        1.0       0.0        no     no
# 195      course   father         1.0        2.0       0.0        no    yes
# 196      course   mother         1.0        1.0       0.0        no     no
# 197        home   father         3.0        1.0       0.0        no    yes
# 198        home   mother         2.0        1.0       1.0        no    yes
# 199  reputation   mother         1.0        2.0       0.0        no    yes
# 200        home   mother         1.0        2.0       0.0        no    yes
# 201  reputation   mother         1.0        2.0       0.0       yes    yes
# 202      course   mother         1.0        2.0       0.0        no    yes
# 203  reputation   mother         1.0        1.0       0.0        no    yes
# 204  reputation   mother         2.0        4.0       0.0        no    yes
# 205        home   mother         1.0        3.0       1.0        no    yes
# 206      course   mother         1.0        2.0       3.0        no    yes
# 207       other   mother         1.0        2.0       0.0        no     no
# 208        home   mother         2.0        1.0       0.0        no    yes
# 209  reputation   mother         2.0        3.0       0.0        no    yes
# 210  reputation    other         1.0        4.0       0.0        no    yes
# 211        home   mother         1.0        2.0       0.0        no    yes
# 212  reputation   mother         1.0        2.0       0.0       yes    yes
# 213        home   mother         1.0        2.0       1.0        no    yes
# 214       other   mother         1.0        1.0       0.0        no    yes
# 215  reputation   mother         2.0        2.0       0.0        no     no
# 216  reputation   mother         1.0        2.0       2.0        no     no
# 217        home   father         1.0        2.0       1.0        no    yes
# 218        home   father         2.0        1.0       0.0        no    yes
# 219      course   mother         1.0        3.0       0.0        no    yes
# 220  reputation   mother         2.0        2.0       0.0        no    yes
# 223        home   mother         2.0        2.0       0.0        no    yes
# 224        home   mother         1.0        3.0       0.0        no    yes
# 225  reputation   mother         1.0        2.0       1.0        no     no
# 226      course   mother         1.0        2.0       0.0        no     no
# 227  reputation   father         1.0        2.0       0.0        no    yes
# 228      course   mother         4.0        2.0       0.0       yes    yes
# 229      course   mother         2.0        3.0       0.0        no     no
# 230  reputation   father         1.0        2.0       0.0        no     no
# 231      course   father         2.0        2.0       0.0        no    yes
# 232  reputation   mother         1.0        2.0       0.0       yes    yes
# 233  reputation   father         1.0        2.0       0.0        no    yes
# 234        home   mother         1.0        2.0       0.0        no    yes
# 235  reputation   mother         2.0        3.0       0.0        no     no
# 236        home   father         1.0        2.0       0.0        no     no
# 237        home   mother         1.0        1.0       0.0        no    yes
# 238      course   mother         3.0        2.0       0.0        no     no
# 240      course   mother         2.0        2.0       0.0        no     no
# 241      course   mother         1.0        2.0       0.0        no    yes
# 243      course   mother         1.0        1.0       0.0        no     no
# 244      course    other         2.0        3.0       0.0        no    yes
# 245      course   mother         3.0        1.0       0.0        no     no
# 246      course   father         2.0        1.0       0.0        no    yes
# 247       other   mother         1.0        1.0       3.0        no     no
# 248      course   mother         1.0        2.0       1.0        no    yes
# 249       other   mother         1.0        1.0       0.0        no     no
# 250      course   mother         2.0        1.0       1.0        no     no
# 251  reputation    other         3.0        2.0       0.0       yes    yes
# 252       other   mother         1.0        1.0       1.0        no     no
# 253      course   mother         2.0        1.0       0.0        no     no
# 254      course   mother         1.0        1.0       0.0        no     no
# 255      course   mother         2.0        1.0       1.0        no    yes
# 256  reputation   mother         1.0        4.0       0.0        no    yes
# 257  reputation   mother         1.0        2.0       0.0        no    yes
# 258        home   mother         1.0        2.0       0.0        no     no
# 260        home   father         1.0        2.0       0.0        no    yes
# 261      course   mother         1.0        2.0       0.0        no    yes
# 262      course   mother         1.0        3.0       0.0        no     no
# 263      course   mother         1.0        3.0       0.0        no     no
# 265  reputation   mother         2.0        2.0       0.0        no    yes
# 266       other   mother         1.0        2.0       0.0        no     no
# 267  reputation   mother         2.0        2.0       0.0        no    yes
# 268  reputation   father         1.0        2.0       0.0        no    yes
# 270        home    other         1.0        2.0       2.0        no    yes
# 271  reputation   father         1.0        4.0       0.0        no    yes
# 272        home   mother         2.0        2.0       0.0        no    yes
# 273        home   mother         1.0        2.0       0.0        no    yes
# 274  reputation   mother         2.0        2.0       0.0        no    yes
# 275      course   mother         2.0        2.0       0.0       yes    yes
# 276        home   mother         2.0        2.0       0.0        no    yes
# ...
# 324   no         no     yes    yes      yes       no     3.0       3.0    3.0
# 325   no        yes     yes    yes      yes       no     4.0       3.0    3.0
# 326   no        yes      no    yes      yes       no     4.0       3.0    5.0
# 327   no         no     yes    yes      yes       no     4.0       4.0    5.0
# 328  yes        yes     yes    yes      yes       no     5.0       4.0    4.0
# 329  yes         no      no    yes      yes      yes     4.0       3.0    3.0
# 330   no        yes     yes    yes      yes       no     4.0       5.0    5.0
# 331   no         no     yes    yes      yes      yes     4.0       4.0    3.0
# 335   no         no     yes    yes      yes       no     4.0       4.0    5.0
# 336  yes         no     yes    yes       no       no     5.0       4.0    3.0
# 338   no         no     yes    yes      yes       no     5.0       3.0    3.0
# 339  yes         no     yes    yes      yes       no     4.0       3.0    3.0
# 340  yes        yes     yes    yes      yes      yes     4.0       3.0    4.0
# 342   no        yes     yes    yes      yes       no     4.0       3.0    3.0
# 344   no         no     yes    yes      yes       no     4.0       3.0    3.0
# 345   no         no     yes    yes      yes      yes     5.0       4.0    3.0
# 346   no         no     yes    yes      yes      yes     5.0       3.0    2.0
# 347  yes         no     yes    yes      yes      yes     4.0       4.0    5.0
# 348  yes        yes     yes    yes      yes      yes     4.0       4.0    3.0
# 349   no         no      no    yes      yes       no     4.0       5.0    5.0
# 350   no         no     yes    yes      yes       no     5.0       4.0    4.0
# 351  yes         no     yes    yes      yes       no     4.0       5.0    4.0
# 352   no         no     yes     no      yes      yes     4.0       3.0    3.0
# 353   no         no     yes    yes      yes       no     4.0       4.0    4.0
# 354  yes        yes      no    yes      yes      yes     4.0       5.0    5.0
# 355   no         no     yes    yes       no      yes     4.0       3.0    4.0
# 356  yes        yes     yes    yes      yes       no     4.0       3.0    3.0
# 357   no         no     yes    yes       no      yes     1.0       2.0    3.0
# 358   no         no      no    yes      yes      yes     3.0       3.0    2.0
# 359   no         no     yes    yes      yes       no     5.0       3.0    2.0
# 360   no         no     yes    yes       no      yes     4.0       3.0    4.0
# 361   no        yes      no     no       no       no     4.0       4.0    3.0
# 362   no         no     yes    yes      yes      yes     4.0       3.0    2.0
# 363  yes        yes     yes    yes      yes      yes     2.0       3.0    4.0
# 364   no         no      no    yes       no       no     3.0       2.0    2.0
# 365  yes         no     yes    yes       no       no     3.0       3.0    4.0
# 366  yes         no     yes    yes      yes      yes     4.0       2.0    2.0
# 368  yes         no     yes    yes      yes      yes     5.0       2.0    3.0
# 369  yes         no      no    yes      yes      yes     3.0       2.0    2.0
# 370   no        yes     yes    yes       no      yes     3.0       2.0    2.0
# 371   no        yes     yes     no      yes      yes     4.0       3.0    3.0
# 372   no        yes     yes    yes       no       no     3.0       4.0    3.0
# 373   no        yes     yes    yes      yes       no     4.0       5.0    5.0
# 374   no         no     yes    yes      yes       no     5.0       4.0    4.0
# 375   no         no     yes    yes      yes       no     4.0       3.0    2.0
# 376  yes         no      no    yes      yes      yes     5.0       4.0    3.0
# 377  yes        yes     yes    yes      yes       no     5.0       4.0    3.0
# 378  yes         no     yes    yes      yes      yes     4.0       1.0    3.0
# 379  yes        yes      no    yes      yes       no     4.0       5.0    4.0
# 380  yes        yes      no    yes      yes       no     3.0       2.0    4.0
# 381   no        yes      no    yes      yes      yes     4.0       4.0    3.0
# 382   no        yes     yes    yes      yes       no     4.0       4.0    3.0
# 384  yes         no     yes    yes      yes       no     5.0       4.0    3.0
# 385  yes         no     yes    yes      yes       no     5.0       3.0    3.0
# 386  yes        yes     yes    yes      yes      yes     4.0       4.0    3.0
# 388  yes         no     yes    yes      yes       no     4.0       3.0    4.0
# 391   no         no      no    yes      yes       no     2.0       4.0    5.0
# 392   no         no      no    yes       no       no     5.0       5.0    3.0
# 393   no        yes      no    yes      yes       no     4.0       4.0    1.0
# 394   no         no     yes    yes      yes       no     3.0       2.0    3.0
#
#      health  absences  score
# 0       3.0       6.0   30.0
# 1       3.0       4.0   30.0
# 2       3.0      10.0   50.0
# 3       5.0       2.0   75.0
# 4       5.0       4.0   50.0
# 5       5.0      10.0   75.0
# 6       3.0       0.0   55.0
# 7       1.0       6.0   30.0
# 8       1.0       0.0   95.0
# 9       5.0       0.0   75.0
# 10      2.0       0.0   45.0
# 11      4.0       4.0   60.0
# 12      5.0       2.0   70.0
# 13      3.0       2.0   55.0
# 14      3.0       0.0   80.0
# 15      2.0       4.0   70.0
# 16      2.0       6.0   70.0
# 17      4.0       4.0   50.0
# 18      5.0      16.0   25.0
# 19      5.0       4.0   50.0
# 20      1.0       0.0   75.0
# 21      5.0       0.0   75.0
# 22      5.0       2.0   80.0
# 23      5.0       0.0   60.0
# 24      5.0       4.0   40.0
# 25      5.0      14.0   40.0
# 26      5.0       2.0   55.0
# 27      1.0       4.0   75.0
# 28      5.0       4.0   55.0
# 29      5.0      16.0   55.0
# 30      5.0       0.0   60.0
# 31      5.0       0.0   85.0
# 32      5.0       0.0   80.0
# 33      2.0       0.0   60.0
# 34      5.0       0.0   75.0
# 35      5.0       0.0   30.0
# 36      4.0       2.0   90.0
# 37      5.0       7.0   75.0
# 38      5.0       2.0   55.0
# 39      2.0       8.0   65.0
# 40      3.0      25.0   55.0
# 41      5.0       8.0   60.0
# 42      5.0       2.0   90.0
# 43      1.0       0.0   55.0
# 44      5.0      14.0   45.0
# 45      5.0       8.0   30.0
# 46      3.0      12.0   55.0
# 47      2.0       4.0  100.0
# 48      5.0       2.0   70.0
# 49      3.0       2.0   35.0
# 50      4.0       2.0   65.0
# 51      5.0       2.0   65.0
# 52      5.0       6.0   50.0
# 53      5.0       0.0   55.0
# 54      1.0       6.0   65.0
# 55      5.0       8.0   50.0
# 56      1.0       0.0   75.0
# 57      5.0       4.0   75.0
# 58      5.0       2.0   45.0
# 59      5.0       2.0   80.0
# 60      4.0       6.0   55.0
# 61      5.0       6.0   55.0
# 62      1.0       4.0   45.0
# 63      4.0       2.0   45.0
# 64      2.0       0.0   50.0
# 65      1.0       2.0   75.0
# 66      3.0       4.0   60.0
# 67      5.0       4.0   30.0
# 68      4.0       2.0   40.0
# 69      3.0      12.0   80.0
# 70      5.0       0.0   75.0
# 71      3.0       0.0   50.0
# 72      5.0       2.0   25.0
# 73      5.0       2.0   70.0
# 74      5.0      54.0   55.0
# 75      5.0       6.0   50.0
# 76      1.0       8.0   50.0
# 77      3.0       0.0   55.0
# 78      3.0       2.0   50.0
# 79      3.0      12.0   25.0
# 80      3.0       2.0   60.0
# 81      5.0       4.0   55.0
# 82      5.0      10.0   30.0
# 83      4.0       4.0   75.0
# 84      4.0       2.0   50.0
# 85      5.0       6.0   40.0
# 86      2.0       4.0   30.0
# 87      1.0       4.0   70.0
# 88      5.0      12.0   50.0
# 89      5.0      18.0   35.0
# 90      4.0       0.0   40.0
# 91      1.0       4.0   90.0
# 92      2.0       4.0   30.0
# 93      1.0       0.0   50.0
# 94      4.0       6.0   70.0
# 95      1.0       2.0   50.0
# 96      4.0       2.0   75.0
# 97      5.0       2.0   50.0
# 98      1.0       6.0   70.0
# 99      3.0       0.0   40.0
# 100     4.0      14.0   25.0
# 101     4.0       4.0   85.0
# 102     5.0       4.0   70.0
# 103     2.0      26.0   30.0
# 104     1.0       0.0   90.0
# 105     4.0      10.0   55.0
# 106     3.0       8.0   40.0
# 107     5.0       2.0   90.0
# 108     1.0       6.0   65.0
# 109     4.0       4.0   80.0
# 110     4.0       6.0   95.0
# 111     2.0       0.0   50.0
# 112     5.0       6.0   65.0
# 113     3.0      10.0   95.0
# 114     5.0       8.0   45.0
# 115     5.0       2.0   80.0
# 116     2.0       2.0   70.0
# 117     5.0       0.0   65.0
# 118     5.0      20.0   40.0
# 119     4.0       6.0   65.0
# 120     1.0       4.0   75.0
# 121     5.0       6.0   75.0
# 122     5.0       2.0   65.0
# 123     5.0      18.0   65.0
# 124     5.0       0.0   40.0
# 125     5.0       0.0   60.0
# 126     1.0       0.0   55.0
# 127     5.0       2.0   45.0
# 129     4.0       4.0   90.0
# 132     5.0      12.0   60.0
# 133     5.0      16.0   55.0
# 138     5.0       0.0   60.0
# 139     5.0       0.0   75.0
# 141     2.0       8.0   45.0
# 142     5.0       2.0   55.0
# 143     1.0       2.0   65.0
# 145     5.0       0.0   55.0
# 147     5.0       2.0   55.0
# 149     5.0       0.0   50.0
# 151     5.0       6.0   70.0
# 152     3.0       8.0   50.0
# 154     4.0       0.0   60.0
# 155     1.0       2.0   40.0
# 156     5.0       8.0   65.0
# 157     4.0       6.0   50.0
# 158     3.0       2.0   75.0
# 159     5.0       4.0   60.0
# 161     3.0       6.0   35.0
# 163     2.0       2.0   50.0
# 164     5.0       0.0   35.0
# 165     2.0      16.0   60.0
# 166     4.0       4.0   50.0
# 167     3.0       0.0   80.0
# 169     3.0       0.0   70.0
# 171     3.0       2.0   80.0
# 172     5.0       4.0   50.0
# 174     4.0       4.0   45.0
# 175     4.0       4.0   45.0
# 176     5.0       2.0   55.0
# 177     4.0       4.0   30.0
# 178     3.0      10.0   45.0
# 179     2.0       4.0   55.0
# 180     3.0      10.0   40.0
# 181     3.0       2.0   60.0
# 182     5.0       0.0   85.0
# 183     1.0      56.0   40.0
# 184     1.0      14.0   60.0
# 185     4.0      12.0   55.0
# 186     3.0       2.0   55.0
# 187     5.0       0.0   75.0
# 188     3.0       6.0   45.0
# 189     5.0       4.0   50.0
# 190     2.0      10.0   65.0
# 191     3.0       0.0   45.0
# 192     5.0      12.0   40.0
# 193     5.0       8.0   50.0
# 194     3.0       0.0   70.0
# 195     5.0       0.0   75.0
# 196     5.0       4.0   80.0
# 197     3.0       8.0   50.0
# 198     2.0      24.0   90.0
# 199     3.0       0.0   50.0
# 200     2.0       2.0   80.0
# 201     4.0       6.0   55.0
# 202     1.0       4.0   50.0
# 203     3.0      18.0   30.0
# 204     5.0       6.0   55.0
# 205     5.0      28.0   45.0
# 206     4.0       5.0   35.0
# 207     1.0      10.0   65.0
# 208     5.0       6.0   50.0
# 209     4.0       6.0   35.0
# 210     3.0      10.0   40.0
# 211     3.0      13.0   65.0
# 212     4.0       0.0   70.0
# 213     5.0      15.0   40.0
# 214     3.0      12.0   50.0
# 215     1.0       4.0   75.0
# 216     1.0      22.0   20.0
# 217     4.0      13.0   40.0
# 218     3.0       3.0   40.0
# 219     4.0       4.0   50.0
# 220     5.0       2.0   30.0
# 223     4.0       0.0   65.0
# 224     5.0       0.0   70.0
# 225     4.0      16.0   35.0
# 226     3.0      10.0   75.0
# 227     3.0       4.0   60.0
# 228     3.0      14.0   45.0
# 229     3.0      10.0   60.0
# 230     3.0      14.0   70.0
# 231     1.0       4.0   55.0
# 232     2.0      14.0   45.0
# 233     1.0       2.0   65.0
# 234     5.0      18.0   30.0
# 235     2.0      10.0   50.0
# 236     5.0       4.0   65.0
# 237     5.0      20.0   60.0
# 238     3.0       2.0   55.0
# 240     5.0      14.0   60.0
# 241     4.0       2.0   60.0
# 243     5.0       0.0   60.0
# 244     3.0       0.0   55.0
# 245     4.0       6.0   90.0
# 246     2.0       4.0   65.0
# 247     1.0      16.0   40.0
# 248     5.0       8.0   25.0
# 249     5.0       0.0   75.0
# 250     5.0       0.0   40.0
# 251     2.0       6.0   50.0
# 252     5.0       4.0   40.0
# 253     3.0       0.0   40.0
# 254     5.0       4.0   60.0
# 255     5.0       2.0   40.0
# 256     5.0       6.0   65.0
# 257     1.0      12.0   55.0
# 258     4.0       8.0   70.0
# 260     2.0      21.0   90.0
# 261     3.0       2.0   40.0
# 262     3.0       1.0   60.0
# 263     4.0       4.0   45.0
# 265     1.0       4.0   85.0
# 266     5.0       2.0   50.0
# 267     4.0       8.0   55.0
# 268     5.0      10.0   50.0
# 270     5.0       4.0   55.0
# 271     2.0       4.0   70.0
# 272     3.0       2.0   55.0
# 273     1.0       2.0   70.0
# 274     1.0       2.0   50.0
# 275     5.0       6.0   60.0
# 276     5.0      75.0   45.0
# 277     3.0      22.0   45.0
# 278     4.0      15.0   40.0
# 279     1.0       8.0   50.0
# 280     5.0      30.0   40.0
# 281     3.0      19.0   50.0
# 282     3.0       1.0   60.0
# 283     4.0       4.0   55.0
# 284     5.0       4.0   55.0
# 285     4.0       2.0   55.0
# 286     2.0       5.0   95.0
# 287     3.0       6.0   60.0
# 288     2.0       6.0   70.0
# 289     2.0       9.0   75.0
# 290     5.0      11.0   55.0
# 291     3.0       0.0   75.0
# 292     5.0      12.0   65.0
# 293     3.0       6.0   90.0
# 294     4.0       8.0   70.0
# 295     5.0       4.0   55.0
# 297     2.0      10.0   40.0
# 298     3.0       0.0   70.0
# 299     1.0       5.0   80.0
# 300     4.0      14.0   55.0
# 301     5.0       0.0   50.0
# 302     3.0       0.0   70.0
# 303     5.0       0.0   90.0
# 304     3.0      20.0   65.0
# 305     3.0       8.0   60.0
# 306     5.0       0.0   90.0
# 307     4.0      38.0   40.0
# 308     5.0       0.0   60.0
# 309     3.0      18.0   50.0
# 311     2.0      20.0   65.0
# 312     4.0       3.0   55.0
# 313     1.0      22.0   55.0
# 314     3.0      14.0   65.0
# 315     3.0      40.0   55.0
# 317     5.0       9.0   45.0
# 318     5.0       0.0   50.0
# 319     5.0       2.0   55.0
# 320     5.0      23.0   65.0
# 321     3.0      12.0   45.0
# 322     3.0       3.0   55.0
# 323     5.0       1.0   75.0
# 324     2.0       0.0   75.0
# 325     3.0       3.0   55.0
# 326     5.0       3.0   80.0
# 327     4.0       8.0   50.0
# 328     4.0       7.0   45.0
# 329     4.0       4.0   70.0
# 330     5.0       2.0   40.0
# 331     5.0       7.0   70.0
# 335     5.0      16.0   75.0
# 336     5.0      12.0   65.0
# 338     1.0       7.0   85.0
# 339     2.0       4.0   50.0
# 340     3.0       4.0   55.0
# 342     5.0      11.0   75.0
# 344     3.0       4.0   50.0
# 345     1.0       7.0   70.0
# 346     4.0       9.0   80.0
# 347     5.0       0.0   45.0
# 348     4.0       0.0   75.0
# 349     5.0      10.0   65.0
# 350     2.0       8.0   55.0
# 351     3.0       2.0   65.0
# 352     3.0       4.0   40.0
# 353     5.0       4.0   40.0
# 354     2.0       4.0   55.0
# 355     5.0       0.0   45.0
# 356     5.0       4.0   65.0
# 357     5.0       2.0   55.0
# 358     3.0       4.0   50.0
# 359     4.0       0.0   80.0
# 360     5.0       0.0   65.0
# 361     5.0       2.0   60.0
# 362     3.0       0.0   50.0
# 363     1.0       0.0   75.0
# 364     3.0       0.0   60.0
# 365     3.0       4.0   50.0
# 366     5.0       0.0   65.0
# 368     4.0       0.0   50.0
# 369     5.0      10.0   55.0
# 370     3.0       4.0   45.0
# 371     3.0       3.0   60.0
# 372     3.0       8.0   55.0
# 373     1.0      14.0   25.0
# 374     1.0       0.0   95.0
# 375     4.0       2.0   50.0
# 376     3.0       4.0   75.0
# 377     2.0       4.0   50.0
# 378     1.0       0.0   75.0
# 379     1.0      17.0   50.0
# 380     2.0       4.0   70.0
# 381     5.0       5.0   35.0
# 382     3.0       2.0   50.0
# 384     3.0      14.0   25.0
# 385     4.0       2.0   50.0
# 386     5.0       7.0   30.0
# 388     1.0       0.0   40.0
# 391     2.0       3.0   80.0
# 392     3.0       3.0   35.0
# 393     5.0       0.0   50.0
# 394     5.0       5.0   45.0

# %%
math[math.score == 0]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, health, absences, score]
# Index: []

# %% [markdown]
# # Корреляционный анализ
#
# Выясним, какие столбцы коррелируют с балом по госэкзамену по математике. Это поможет понять, какие параметры стоит оставить для модели, а какие — исключить.
#
# Корреляции рассмотрим только для числовых столбцов.
#
# Для быстрого построения графиков зависимости переменных можно воспользоваться функцией pairplot из модуля seaborn:

# %%
sns.pairplot(math, kind = 'reg')
